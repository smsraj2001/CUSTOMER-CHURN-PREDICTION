# %% [markdown]
# # CUSTOMER CHURN PREDICTION

# %% [markdown]
# #### DETAILS
# ##### NAME   : S M SUTHARSAN RAJ
# ##### TOPIC  : CUSTOMER CHURN PREDICTION

# %%
# IMPORTING THE LIBRARIES
# GENERAL LIBRARIES FOR DATASET
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime as dt
import math
# FOR ID3 DECISION TREE
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from numpy import log2 as log
# FOR SVM
from sklearn.svm import SVC
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
# FOR ANN
from sklearn.neural_network import MLPClassifier
# FOR THE STATISTICS IN EACH MODEL
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### READING AND CLEANING THE DATASET

# %%
# READING THE DATASET
path = '' # Enter your path to the dataset
df = pd.read_csv(path, encoding = 'latin1')
df2 = pd.read_csv(path, encoding = 'latin1')

# %%
# CLEANING UP THE DATA
def clean(df):
    df = df.dropna()
    df = df.astype({'CustomerID':'int'})
    df = df[df['CustomerID'] > 0]
    df = df[df['StockCode'] != 'POST']
    df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'],format='%d-%m-%Y %H:%M',infer_datetime_format=True)
    return df

df = clean(df)
df2 = clean(df2)
mask1 = (df['InvoiceDate'] >= '01-12-2010') & (df['InvoiceDate'] <= '31-08-2011')
df_1 = df.loc[mask1]
mask2 = (df2['InvoiceDate'] >= '01-09-2011') & (df2['InvoiceDate'] <= '31-12-2011') & (df2['Quantity'] > 0)
df_2 = df2.loc[mask2]

# DISPLAYING THE 2 DATASETS
display("DF1",df_1) # First range of dates
display("DF2",df_2) # Second range of dates
# Out:
# 'DF1'
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 319395    564852     82552                  WASHROOM METAL SIGN        10
# 319396    564852     21756             BATH BUILDING BLOCK WORD         3
# 319397    564852     21908        CHOCOLATE THIS WAY METAL SIGN         7
# 319398    564852     22116      METAL SIGN HIS DINNER IS SERVED        10
# 319399    564852     23091           ZINC HERB GARDEN CONTAINER         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                    ...        ...         ...             ...
# 319395 2011-08-30 17:23:00       1.45       14976  United Kingdom
# 319396 2011-08-30 17:23:00       5.95       14976  United Kingdom
# 319397 2011-08-30 17:23:00       2.10       14976  United Kingdom
# 319398 2011-08-30 17:23:00       0.79       14976  United Kingdom
# 319399 2011-08-30 17:23:00       6.25       14976  United Kingdom
#
# [230474 rows x 8 columns]
# 'DF2'
#        InvoiceNo StockCode                       Description  Quantity  \
# 49034     540498     21485  RETROSPOT HEART HOT WATER BOTTLE         1
# 49035     540498     22112        CHOCOLATE HOT WATER BOTTLE         1
# 49036     540498    17091A           LAVENDER INCENSE IN TIN         6
# 49037     540498     84813     SET OF 4 DIAMOND NAPKIN RINGS         6
# 49038     540498     22795      SWEETHEART RECIPE BOOK STAND         3
# ...          ...       ...                               ...       ...
# 541904    581587     22613       PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255   CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 49034  2011-01-09 10:06:00       4.95       17243  United Kingdom
# 49035  2011-01-09 10:06:00       4.95       17243  United Kingdom
# 49036  2011-01-09 10:06:00       1.25       17243  United Kingdom
# 49037  2011-01-09 10:06:00      12.75       17243  United Kingdom
# 49038  2011-01-09 10:06:00       6.75       17243  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85       12680          France
# 541905 2011-12-09 12:50:00       2.10       12680          France
# 541906 2011-12-09 12:50:00       4.15       12680          France
# 541907 2011-12-09 12:50:00       4.15       12680          France
# 541908 2011-12-09 12:50:00       4.95       12680          France
#
# [366609 rows x 8 columns]

# %% [markdown]
# ### CREATING THE TARGET VARIABLE

# %%
# MARKING CHURN AND NON-CHURN CUSTOMERS
df_1['Churn'] = np.in1d(df_1['CustomerID'], df_2['CustomerID'])
df_1['Churn'] = df_1['Churn'].map({True: 'Not Churn', False: 'Churn'})

# %% [markdown]
# #### DISPLAYING THE TRAINING SET

# %%
# DISPLAYING DATA| OF "CHURN" CUSTOMERS
df_3 = df_1[df_1["Churn"] == "Churn"]
display("ONLY CHURN", df_3)
# Out:
# 'ONLY CHURN'
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 268027   C560372         M                               Manual        -1
# 268431   C560420         M                               Manual        -1
# 268476   C560430         M                               Manual        -1
# 270557   C560572         M                               Manual        -1
# 270559   C560574         M                               Manual        -1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Churn
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom  Churn
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom  Churn
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom  Churn
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom  Churn
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom  Churn
# ...                    ...        ...         ...             ...    ...
# 268027 2011-07-18 12:26:00    4287.63       17448  United Kingdom  Churn
# 268431 2011-07-18 15:11:00    1592.49       15369  United Kingdom  Churn
# 268476 2011-07-18 15:21:00     611.86       13154  United Kingdom  Churn
# 270557 2011-07-19 14:45:00     112.35       17065  United Kingdom  Churn
# 270559 2011-07-19 14:56:00     106.40       14437  United Kingdom  Churn
#
# [3261 rows x 9 columns]

# %% [markdown]
# ### CUSTOMER LEVEL FEATURE SELECTION

# %% [markdown]
# #### FEATURE 1 : DISPLAYING ONLY PRODUCT NAMES

# %%
def get_product_name(x):
    max_upper_count = 0
    product_name = ''
    for i in x:
        if(i == i):  #To Check for NaN
            count = 0
            for letter in i:
                if(letter.isupper()):
                    count = count+1
            if count>max_upper_count:
                max_upper_count = count
                product_name = i
    return product_name
grouped = df_3.groupby("StockCode")['Description'].unique()
lookup = grouped.apply(get_product_name)
display(lookup)
# Out:
# StockCode
# 10002                 INFLATABLE POLITICAL GLOBE
# 10120                                DOGGY RUBBER
# 10123C                      HEARTS WRAPPING TAPE
# 10125                     MINI FUNKY DESIGN TAPES
# 10135                COLOURING PENCILS BROWN TUBE
#                               ...
# 90210B               CLEAR ACRYLIC FACETED BANGLE
# 90211B          JET BLACK LAS VEGAS NECKLACE 45CM
# BANK CHARGES                         Bank Charges
# C2                                       CARRIAGE
# M                                          Manual
# Name: Description, Length: 1312, dtype: object

# %% [markdown]
# #### FEATURE 2 : COUNTRY CODE

# %%
# COUNTRY CODE INSTEAD OF COUNTRY NAMES
countries_dict = {}

countries = df_3['Country'].unique()
for i,y in enumerate(countries):
    countries_dict[y] = i

df_3['Country'] = [countries_dict[x] for x in df_3['Country']]
df_3['Country'].unique()
df_3.head()
display(df_3.count())
# Out:
# InvoiceNo      3261
# StockCode      3261
# Description    3261
# Quantity       3261
# InvoiceDate    3261
# UnitPrice      3261
# CustomerID     3261
# Country        3261
# Churn          3261
# dtype: int64

# %% [markdown]
# #### FEATURE 3 : USING STOCKCODE

# %%
print("STOCK CODE LENGTH : ",len(df_3['StockCode'].unique()))
# Out:
# STOCK CODE LENGTH :  1312

# %% [markdown]
# #### FEATURE 4 : STATISTICS FEATURE

# %%
# DATA MODIFICATION FOR PLOT
df_3_3 = df_3.copy()
df_3_3['Churn'] = df_3_3['Churn'].map({"Churn": 1, "Not Churn": 0})
df_3_3['StockCode'] = df_3_3['StockCode'].str.replace('\D', '')
df_3_3 = df_3_3[df_3_3['StockCode']!='']
df_3_3['StockCode'] = df_3_3['StockCode'].astype(int)

# PLOTTING THE DATA
sns.jointplot(data = df_3_3, x = 'Country', y = 'Churn', kind = 'reg', color = 'purple')
sns.jointplot(data = df_3_3, x = 'StockCode', y = 'Churn', kind = 'reg', color = 'purple')
sns.jointplot(data = df_3_3, x = 'UnitPrice', y = 'Churn', kind = 'reg', color = 'purple')
sns.jointplot(data = df_3_3, x = 'CustomerID', y = 'Churn', kind = 'reg', color = 'purple')
sns.jointplot(data = df_3_3, x = 'Quantity', y = 'Churn', kind = 'reg', color = 'purple')

# %%
sns.heatmap(df_3_3.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### CONSTRUCT A DECISION TREE USING ID3

# %%
# Construct a Decision Tree using ID3 algorithm and classify whether the customer will Churn/Not Churn
eps = np.finfo(float).eps
def find_entropy(df):
    Class = df.keys()[-1]   #To make the code generic, changing target variable class name
    entropy = 0
    values = df[Class].unique()
    for value in values:
        fraction = df[Class].value_counts()[value]/len(df[Class])
        entropy += -fraction * np.log2(fraction)
    return entropy
  
  
def find_entropy_attribute(df,attribute):
  Class = df.keys()[-1]   #To make the code generic, changing target variable class name
  target_variables = df[Class].unique()  #This gives all 'Yes' and 'No'
  variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
  entropy2 = 0
  for variable in variables:
      entropy = 0
      for target_variable in target_variables:
          num = len(df[attribute][df[attribute] == variable][df[Class] == target_variable])
          den = len(df[attribute][df[attribute] == variable])
          fraction = num/(den+eps)
          entropy += -fraction * log(fraction+eps)
      fraction2 = den/len(df)
      entropy2 += -fraction2 * entropy
  return abs(entropy2)


def find_winner(df):
    Entropy_att = []
    IG = []
    for key in df.keys()[:-1]:
        IG.append(find_entropy(df) - find_entropy_attribute(df,key))
    return df.keys()[:-1][np.argmax(IG)]
  
  
def get_subtable(df, node, value):
  return df[df[node] == value].reset_index(drop = True)


def buildTree(df,tree = None): 
    Class = df.keys()[-1] # To make the code generic, changing target variable class name
    # Here we build our decision tree
    # Get attribute with maximum information gain
    node = find_winner(df)
    
    # Get distinct value of that attribute e.g Salary is node and Low,Med and High are values
    attValue = np.unique(df[node])
    
    # Create an empty dictionary to create tree    
    if tree is None:                    
        tree = {}
        tree[node] = {}
    
    # We make loop to construct a tree by calling this function recursively. 
    # In this we check if the subset is pure and stops if it is pure. 

    for value in attValue:
        
        subtable = get_subtable(df,node,value)
        clValue,counts = np.unique(subtable['Churn'],return_counts = True)                        
        
        if len(counts) == 1: #Checking purity of subset
            tree[node][value] = clValue[0]                                                    
        else:        
            tree[node][value] = buildTree(subtable) #Calling the function recursively 
                   
    return tree

t = buildTree(df_1)

# %%
print("The DECISION TREE in \'Dictionary\' Format :\n")
display(t)
# Out:
# The DECISION TREE in 'Dictionary' Format :
# {'InvoiceNo': {'536365': 'Churn',
#   '536366': 'Churn',
#   '536367': 'Not Churn',
#   '536368': 'Not Churn',
#   '536369': 'Not Churn',
#   '536370': 'Not Churn',
#   '536371': 'Not Churn',
#   '536372': 'Churn',
#   '536373': 'Churn',
#   '536374': 'Not Churn',
#   '536375': 'Churn',
#   '536376': 'Not Churn',
#   '536377': 'Churn',
#   '536378': 'Not Churn',
#   '536380': 'Not Churn',
#   '536381': 'Not Churn',
#   '536382': 'Not Churn',
#   '536384': 'Churn',
#   '536385': 'Not Churn',
#   '536386': 'Not Churn',
#   '536387': 'Not Churn',
#   '536388': 'Not Churn',
#   '536389': 'Not Churn',
#   '536390': 'Not Churn',
#   '536392': 'Not Churn',
#   '536393': 'Churn',
#   '536394': 'Not Churn',
#   '536395': 'Not Churn',
#   '536396': 'Churn',
#   '536397': 'Not Churn',
#   '536398': 'Not Churn',
#   '536399': 'Churn',
#   '536400': 'Not Churn',
#   '536401': 'Not Churn',
#   '536402': 'Not Churn',
#   '536403': 'Churn',
#   '536404': 'Not Churn',
#   '536405': 'Not Churn',
#   '536406': 'Churn',
#   '536407': 'Churn',
#   '536408': 'Not Churn',
#   '536409': 'Churn',
#   '536412': 'Not Churn',
#   '536415': 'Not Churn',
#   '536416': 'Not Churn',
#   '536420': 'Churn',
#   '536423': 'Not Churn',
#   '536425': 'Not Churn',
#   '536437': 'Not Churn',
#   '536446': 'Not Churn',
#   '536460': 'Not Churn',
#   '536463': 'Not Churn',
#   '536464': 'Churn',
#   '536466': 'Not Churn',
#   '536477': 'Not Churn',
#   '536488': 'Not Churn',
#   '536500': 'Not Churn',
#   '536502': 'Not Churn',
#   '536508': 'Not Churn',
#   '536514': 'Not Churn',
#   '536520': 'Churn',
#   '536521': 'Not Churn',
#   '536522': 'Not Churn',
#   '536523': 'Not Churn',
#   '536524': 'Not Churn',
#   '536525': 'Not Churn',
#   '536526': 'Not Churn',
#   '536527': 'Not Churn',
#   '536528': 'Not Churn',
#   '536529': 'Churn',
#   '536530': 'Not Churn',
#   '536531': 'Not Churn',
#   '536532': 'Not Churn',
#   '536533': 'Not Churn',
#   '536534': 'Churn',
#   '536535': 'Not Churn',
#   '536536': 'Not Churn',
#   '536537': 'Churn',
#   '536538': 'Not Churn',
#   '536539': 'Churn',
#   '536540': 'Not Churn',
#   '536541': 'Not Churn',
#   '536542': 'Not Churn',
#   '536551': 'Not Churn',
#   '536556': 'Churn',
#   '536557': 'Not Churn',
#   '536559': 'Not Churn',
#   '536560': 'Not Churn',
#   '536561': 'Not Churn',
#   '536562': 'Not Churn',
#   '536563': 'Not Churn',
#   '536564': 'Not Churn',
#   '536566': 'Not Churn',
#   '536567': 'Churn',
#   '536568': 'Churn',
#   '536569': 'Churn',
#   '536570': 'Not Churn',
#   '536571': 'Not Churn',
#   '536572': 'Not Churn',
#   '536573': 'Not Churn',
#   '536574': 'Not Churn',
#   '536575': 'Not Churn',
#   '536576': 'Not Churn',
#   '536577': 'Not Churn',
#   '536578': 'Not Churn',
#   '536579': 'Not Churn',
#   '536580': 'Not Churn',
#   '536581': 'Not Churn',
#   '536582': 'Not Churn',
#   '536583': 'Not Churn',
#   '536584': 'Not Churn',
#   '536585': 'Not Churn',
#   '536586': 'Not Churn',
#   '536587': 'Churn',
#   '536588': 'Not Churn',
#   '536590': 'Churn',
#   '536591': 'Not Churn',
#   '536593': 'Not Churn',
#   '536594': 'Not Churn',
#   '536595': 'Not Churn',
#   '536597': 'Churn',
#   '536598': 'Not Churn',
#   '536599': 'Not Churn',
#   '536600': 'Churn',
#   '536601': 'Churn',
#   '536602': 'Churn',
#   '536603': 'Churn',
#   '536604': 'Not Churn',
#   '536605': 'Not Churn',
#   '536607': 'Churn',
#   '536608': 'Churn',
#   '536609': 'Churn',
#   '536610': 'Churn',
#   '536611': 'Not Churn',
#   '536612': 'Churn',
#   '536613': 'Churn',
#   '536614': 'Churn',
#   '536615': 'Not Churn',
#   '536616': 'Churn',
#   '536617': 'Not Churn',
#   '536618': 'Not Churn',
#   '536619': 'Not Churn',
#   '536620': 'Not Churn',
#   '536621': 'Churn',
#   '536623': 'Not Churn',
#   '536624': 'Not Churn',
#   '536626': 'Not Churn',
#   '536627': 'Not Churn',
#   '536628': 'Churn',
#   '536629': 'Churn',
#   '536630': 'Churn',
#   '536631': 'Churn',
#   '536632': 'Not Churn',
#   '536633': 'Not Churn',
#   '536634': 'Not Churn',
#   '536635': 'Not Churn',
#   '536636': 'Churn',
#   '536637': 'Not Churn',
#   '536638': 'Not Churn',
#   '536639': 'Not Churn',
#   '536641': 'Not Churn',
#   '536643': 'Not Churn',
#   '536663': 'Not Churn',
#   '536667': 'Not Churn',
#   '536670': 'Not Churn',
#   '536671': 'Not Churn',
#   '536672': 'Not Churn',
#   '536673': 'Not Churn',
#   '536674': 'Churn',
#   '536676': 'Churn',
#   '536681': 'Not Churn',
#   '536685': 'Churn',
#   '536688': 'Churn',
#   '536690': 'Churn',
#   '536693': 'Churn',
#   '536698': 'Churn',
#   '536707': 'Not Churn',
#   '536732': 'Not Churn',
#   '536733': 'Not Churn',
#   '536735': 'Not Churn',
#   '536736': 'Not Churn',
#   '536738': 'Not Churn',
#   '536739': 'Not Churn',
#   '536740': 'Not Churn',
#   '536741': 'Not Churn',
#   '536742': 'Not Churn',
#   '536743': 'Not Churn',
#   '536744': 'Not Churn',
#   '536745': 'Not Churn',
#   '536746': 'Churn',
#   '536747': 'Not Churn',
#   '536748': 'Not Churn',
#   '536749': 'Churn',
#   '536750': 'Churn',
#   '536751': 'Churn',
#   '536752': 'Churn',
#   '536753': 'Churn',
#   '536754': 'Not Churn',
#   '536759': 'Churn',
#   '536761': 'Not Churn',
#   '536762': 'Not Churn',
#   '536763': 'Not Churn',
#   '536769': 'Not Churn',
#   '536771': 'Not Churn',
#   '536777': 'Not Churn',
#   '536778': 'Not Churn',
#   '536779': 'Churn',
#   '536781': 'Not Churn',
#   '536782': 'Not Churn',
#   '536783': 'Not Churn',
#   '536784': 'Not Churn',
#   '536785': 'Not Churn',
#   '536786': 'Not Churn',
#   '536787': 'Churn',
#   '536788': 'Not Churn',
#   '536789': 'Churn',
#   '536790': 'Churn',
#   '536791': 'Churn',
#   '536792': 'Not Churn',
#   '536793': 'Not Churn',
#   '536794': 'Not Churn',
#   '536795': 'Not Churn',
#   '536796': 'Not Churn',
#   '536797': 'Not Churn',
#   '536798': 'Not Churn',
#   '536799': 'Not Churn',
#   '536800': 'Not Churn',
#   '536802': 'Not Churn',
#   '536803': 'Not Churn',
#   '536804': 'Not Churn',
#   '536805': 'Not Churn',
#   '536806': 'Not Churn',
#   '536808': 'Not Churn',
#   '536809': 'Not Churn',
#   '536810': 'Not Churn',
#   '536811': 'Not Churn',
#   '536813': 'Not Churn',
#   '536819': 'Not Churn',
#   '536821': 'Not Churn',
#   '536823': 'Churn',
#   '536824': 'Not Churn',
#   '536830': 'Churn',
#   '536831': 'Not Churn',
#   '536832': 'Not Churn',
#   '536833': 'Not Churn',
#   '536834': 'Churn',
#   '536835': 'Not Churn',
#   '536836': 'Not Churn',
#   '536837': 'Not Churn',
#   '536838': 'Not Churn',
#   '536839': 'Not Churn',
#   '536840': 'Churn',
#   '536841': 'Not Churn',
#   '536842': 'Not Churn',
#   '536843': 'Not Churn',
#   '536844': 'Not Churn',
#   '536845': 'Not Churn',
#   '536846': 'Not Churn',
#   '536847': 'Not Churn',
#   '536848': 'Not Churn',
#   '536849': 'Not Churn',
#   '536851': 'Churn',
#   '536852': 'Churn',
#   '536856': 'Churn',
#   '536857': 'Not Churn',
#   '536858': 'Not Churn',
#   '536859': 'Not Churn',
#   '536860': 'Not Churn',
#   '536861': 'Not Churn',
#   '536863': 'Churn',
#   '536874': 'Not Churn',
#   '536884': 'Churn',
#   '536890': 'Not Churn',
#   '536938': 'Not Churn',
#   '536943': 'Not Churn',
#   '536944': 'Not Churn',
#   '536945': 'Not Churn',
#   '536946': 'Not Churn',
#   '536947': 'Not Churn',
#   '536954': 'Not Churn',
#   '536956': 'Not Churn',
#   '536957': 'Not Churn',
#   '536960': 'Not Churn',
#   '536967': 'Not Churn',
#   '536968': 'Not Churn',
#   '536969': 'Not Churn',
#   '536970': 'Not Churn',
#   '536971': 'Not Churn',
#   '536972': 'Churn',
#   '536973': 'Not Churn',
#   '536974': 'Not Churn',
#   '536975': 'Not Churn',
#   '536976': 'Not Churn',
#   '536977': 'Not Churn',
#   '536980': 'Not Churn',
#   '536981': 'Not Churn',
#   '536983': 'Not Churn',
#   '536984': 'Not Churn',
#   '536985': 'Not Churn',
#   '536986': 'Not Churn',
#   '536987': 'Not Churn',
#   '536988': 'Not Churn',
#   '536989': 'Not Churn',
#   '536990': 'Not Churn',
#   '536992': 'Not Churn',
#   '536993': 'Not Churn',
#   '536994': 'Not Churn',
#   '537022': 'Churn',
#   '537023': 'Not Churn',
#   '537026': 'Not Churn',
#   '537030': 'Not Churn',
#   '537031': 'Not Churn',
#   '537034': 'Not Churn',
#   '537035': 'Not Churn',
#   '537036': 'Not Churn',
#   '537037': 'Not Churn',
#   '537038': 'Not Churn',
#   '537040': 'Not Churn',
#   '537041': 'Not Churn',
#   '537042': 'Not Churn',
#   '537044': 'Not Churn',
#   '537045': 'Not Churn',
#   '537046': 'Not Churn',
#   '537047': 'Not Churn',
#   '537048': 'Not Churn',
#   '537049': 'Not Churn',
#   '537050': 'Not Churn',
#   '537051': 'Not Churn',
#   '537052': 'Not Churn',
#   '537053': 'Not Churn',
#   '537054': 'Not Churn',
#   '537055': 'Not Churn',
#   '537057': 'Not Churn',
#   '537058': 'Not Churn',
#   '537059': 'Churn',
#   '537065': 'Not Churn',
#   '537067': 'Churn',
#   '537077': 'Not Churn',
#   '537081': 'Churn',
#   '537086': 'Churn',
#   '537090': 'Churn',
#   '537111': 'Not Churn',
#   '537117': 'Not Churn',
#   '537126': 'Not Churn',
#   '537127': 'Not Churn',
#   '537128': 'Not Churn',
#   '537129': 'Not Churn',
#   '537130': 'Not Churn',
#   '537131': 'Not Churn',
#   '537133': 'Not Churn',
#   '537134': 'Not Churn',
#   '537135': 'Not Churn',
#   '537136': 'Not Churn',
#   '537137': 'Not Churn',
#   '537138': 'Not Churn',
#   '537139': 'Not Churn',
#   '537140': 'Not Churn',
#   '537141': 'Not Churn',
#   '537142': 'Not Churn',
#   '537144': 'Churn',
#   '537153': 'Churn',
#   '537154': 'Not Churn',
#   '537155': 'Not Churn',
#   '537156': 'Not Churn',
#   '537158': 'Not Churn',
#   '537159': 'Not Churn',
#   '537160': 'Not Churn',
#   '537163': 'Not Churn',
#   '537176': 'Not Churn',
#   '537179': 'Not Churn',
#   '537192': 'Not Churn',
#   '537193': 'Not Churn',
#   '537194': 'Not Churn',
#   '537195': 'Not Churn',
#   '537196': 'Not Churn',
#   '537197': 'Not Churn',
#   '537198': 'Not Churn',
#   '537199': 'Not Churn',
#   '537200': 'Not Churn',
#   '537201': 'Not Churn',
#   '537202': 'Not Churn',
#   '537204': 'Not Churn',
#   '537205': 'Not Churn',
#   '537206': 'Not Churn',
#   '537207': 'Not Churn',
#   '537208': 'Not Churn',
#   '537209': 'Not Churn',
#   '537210': 'Not Churn',
#   '537211': 'Not Churn',
#   '537212': 'Not Churn',
#   '537213': 'Not Churn',
#   '537214': 'Not Churn',
#   '537215': 'Not Churn',
#   '537216': 'Not Churn',
#   '537217': 'Not Churn',
#   '537218': 'Not Churn',
#   '537219': 'Not Churn',
#   '537221': 'Not Churn',
#   '537222': 'Not Churn',
#   '537223': 'Not Churn',
#   '537224': 'Not Churn',
#   '537225': 'Not Churn',
#   '537226': 'Not Churn',
#   '537227': 'Not Churn',
#   '537228': 'Not Churn',
#   '537229': 'Not Churn',
#   '537231': 'Not Churn',
#   '537233': 'Not Churn',
#   '537235': 'Not Churn',
#   '537236': 'Churn',
#   '537238': 'Not Churn',
#   '537239': 'Not Churn',
#   '537241': 'Not Churn',
#   '537242': 'Not Churn',
#   '537243': 'Not Churn',
#   '537244': 'Not Churn',
#   '537245': 'Not Churn',
#   '537246': 'Not Churn',
#   '537247': 'Not Churn',
#   '537248': 'Churn',
#   '537249': 'Not Churn',
#   '537250': 'Not Churn',
#   '537254': 'Not Churn',
#   '537255': 'Not Churn',
#   '537256': 'Not Churn',
#   '537257': 'Churn',
#   '537258': 'Not Churn',
#   '537262': 'Not Churn',
#   '537265': 'Not Churn',
#   '537298': 'Not Churn',
#   '537301': 'Not Churn',
#   '537312': 'Not Churn',
#   '537313': 'Not Churn',
#   '537332': 'Not Churn',
#   '537334': 'Not Churn',
#   '537335': 'Not Churn',
#   '537346': 'Not Churn',
#   '537350': 'Not Churn',
#   '537351': 'Not Churn',
#   '537354': 'Not Churn',
#   '537359': 'Not Churn',
#   '537360': 'Churn',
#   '537362': 'Not Churn',
#   '537365': 'Not Churn',
#   '537366': 'Not Churn',
#   '537367': 'Not Churn',
#   '537368': 'Not Churn',
#   '537369': 'Churn',
#   '537370': 'Not Churn',
#   '537371': 'Not Churn',
#   '537372': 'Not Churn',
#   '537374': 'Not Churn',
#   '537375': 'Not Churn',
#   '537376': 'Not Churn',
#   '537377': 'Not Churn',
#   '537378': 'Not Churn',
#   '537380': 'Not Churn',
#   '537381': 'Not Churn',
#   '537382': 'Not Churn',
#   '537384': 'Not Churn',
#   '537385': 'Not Churn',
#   '537386': 'Not Churn',
#   '537387': 'Not Churn',
#   '537388': 'Not Churn',
#   '537389': 'Not Churn',
#   '537390': 'Churn',
#   '537391': 'Not Churn',
#   '537392': 'Not Churn',
#   '537393': 'Not Churn',
#   '537394': 'Not Churn',
#   '537395': 'Not Churn',
#   '537396': 'Not Churn',
#   '537397': 'Not Churn',
#   '537399': 'Not Churn',
#   '537400': 'Not Churn',
#   '537403': 'Not Churn',
#   '537404': 'Not Churn',
#   '537405': 'Not Churn',
#   '537407': 'Not Churn',
#   '537409': 'Not Churn',
#   '537410': 'Not Churn',
#   '537412': 'Not Churn',
#   '537415': 'Not Churn',
#   '537418': 'Not Churn',
#   '537419': 'Not Churn',
#   '537420': 'Not Churn',
#   '537421': 'Not Churn',
#   '537422': 'Not Churn',
#   '537423': 'Not Churn',
#   '537424': 'Not Churn',
#   '537428': 'Not Churn',
#   '537429': 'Not Churn',
#   '537433': 'Not Churn',
#   '537435': 'Not Churn',
#   '537440': 'Not Churn',
#   '537441': 'Not Churn',
#   '537446': 'Not Churn',
#   '537447': 'Not Churn',
#   '537448': 'Not Churn',
#   '537456': 'Not Churn',
#   '537457': 'Not Churn',
#   '537458': 'Not Churn',
#   '537459': 'Not Churn',
#   '537460': 'Not Churn',
#   '537461': 'Churn',
#   '537462': 'Not Churn',
#   '537463': 'Not Churn',
#   '537464': 'Not Churn',
#   '537465': 'Not Churn',
#   '537467': 'Not Churn',
#   '537468': 'Not Churn',
#   '537469': 'Not Churn',
#   '537470': 'Not Churn',
#   '537471': 'Not Churn',
#   '537472': 'Not Churn',
#   '537476': 'Not Churn',
#   '537484': 'Not Churn',
#   '537489': 'Not Churn',
#   '537509': 'Not Churn',
#   '537523': 'Not Churn',
#   '537538': 'Not Churn',
#   '537567': 'Churn',
#   '537592': 'Not Churn',
#   '537593': 'Not Churn',
#   '537594': 'Not Churn',
#   '537595': 'Not Churn',
#   '537598': 'Not Churn',
#   '537599': 'Not Churn',
#   '537601': 'Not Churn',
#   '537603': 'Not Churn',
#   '537604': 'Not Churn',
#   '537605': 'Not Churn',
#   '537606': 'Not Churn',
#   '537607': 'Not Churn',
#   '537608': 'Not Churn',
#   '537609': 'Not Churn',
#   '537612': 'Not Churn',
#   '537614': 'Not Churn',
#   '537615': 'Not Churn',
#   '537616': 'Not Churn',
#   '537617': 'Not Churn',
#   '537618': 'Not Churn',
#   '537619': 'Churn',
#   '537620': 'Not Churn',
#   '537622': 'Not Churn',
#   '537623': 'Not Churn',
#   '537624': 'Not Churn',
#   '537625': 'Churn',
#   '537626': 'Not Churn',
#   '537627': 'Not Churn',
#   '537628': 'Not Churn',
#   '537629': 'Not Churn',
#   '537631': 'Not Churn',
#   '537634': 'Not Churn',
#   '537635': 'Not Churn',
#   '537636': 'Not Churn',
#   '537646': 'Not Churn',
#   '537648': 'Not Churn',
#   '537649': 'Churn',
#   '537650': 'Churn',
#   '537653': 'Not Churn',
#   '537655': 'Not Churn',
#   '537657': 'Not Churn',
#   '537658': 'Not Churn',
#   '537659': 'Not Churn',
#   '537664': 'Not Churn',
#   '537665': 'Not Churn',
#   '537667': 'Not Churn',
#   '537668': 'Churn',
#   '537669': 'Not Churn',
#   '537670': 'Not Churn',
#   '537671': 'Not Churn',
#   '537672': 'Not Churn',
#   '537673': 'Not Churn',
#   '537674': 'Not Churn',
#   '537676': 'Churn',
#   '537678': 'Not Churn',
#   '537680': 'Not Churn',
#   '537681': 'Not Churn',
#   '537682': 'Not Churn',
#   '537683': 'Not Churn',
#   '537685': 'Not Churn',
#   '537686': 'Not Churn',
#   '537688': 'Not Churn',
#   '537689': 'Not Churn',
#   '537690': 'Not Churn',
#   '537691': 'Not Churn',
#   '537692': 'Not Churn',
#   '537693': 'Churn',
#   '537694': 'Not Churn',
#   '537698': 'Not Churn',
#   '537700': 'Not Churn',
#   '537707': 'Not Churn',
#   '537738': 'Not Churn',
#   '537743': 'Not Churn',
#   '537751': 'Not Churn',
#   '537754': 'Not Churn',
#   '537755': 'Not Churn',
#   '537757': 'Not Churn',
#   '537758': 'Not Churn',
#   '537759': 'Not Churn',
#   '537760': 'Churn',
#   '537761': 'Not Churn',
#   '537762': 'Not Churn',
#   '537764': 'Churn',
#   '537765': 'Not Churn',
#   '537766': 'Not Churn',
#   '537767': 'Not Churn',
#   '537768': 'Not Churn',
#   '537769': 'Not Churn',
#   '537770': 'Not Churn',
#   '537771': 'Not Churn',
#   '537772': 'Not Churn',
#   '537773': 'Not Churn',
#   '537774': 'Not Churn',
#   '537775': 'Not Churn',
#   '537780': 'Not Churn',
#   '537781': 'Not Churn',
#   '537789': 'Not Churn',
#   '537791': 'Not Churn',
#   '537792': 'Not Churn',
#   '537793': 'Not Churn',
#   '537794': 'Not Churn',
#   '537795': 'Not Churn',
#   '537796': 'Not Churn',
#   '537799': 'Not Churn',
#   '537800': 'Not Churn',
#   '537801': 'Churn',
#   '537802': 'Not Churn',
#   '537803': 'Not Churn',
#   '537804': 'Not Churn',
#   '537806': 'Not Churn',
#   '537808': 'Not Churn',
#   '537809': 'Not Churn',
#   '537810': 'Not Churn',
#   '537811': 'Not Churn',
#   '537813': 'Not Churn',
#   '537815': 'Not Churn',
#   '537816': 'Churn',
#   '537817': 'Churn',
#   '537818': 'Not Churn',
#   '537819': 'Not Churn',
#   '537822': 'Not Churn',
#   '537825': 'Not Churn',
#   '537826': 'Not Churn',
#   '537827': 'Churn',
#   '537828': 'Not Churn',
#   '537829': 'Not Churn',
#   '537830': 'Not Churn',
#   '537831': 'Not Churn',
#   '537833': 'Churn',
#   '537836': 'Not Churn',
#   '537837': 'Not Churn',
#   '537840': 'Not Churn',
#   '537841': 'Not Churn',
#   '537842': 'Not Churn',
#   '537843': 'Not Churn',
#   '537844': 'Not Churn',
#   '537845': 'Not Churn',
#   '537846': 'Churn',
#   '537847': 'Not Churn',
#   '537848': 'Not Churn',
#   '537849': 'Not Churn',
#   '537850': 'Not Churn',
#   '537851': 'Not Churn',
#   '537852': 'Not Churn',
#   '537854': 'Not Churn',
#   '537855': 'Not Churn',
#   '537859': 'Not Churn',
#   '537861': 'Not Churn',
#   '537862': 'Not Churn',
#   '537863': 'Not Churn',
#   '537864': 'Not Churn',
#   '537865': 'Not Churn',
#   '537866': 'Not Churn',
#   '537867': 'Not Churn',
#   '537868': 'Not Churn',
#   '537871': 'Not Churn',
#   '537879': 'Not Churn',
#   '537880': 'Not Churn',
#   '537881': 'Not Churn',
#   '537882': 'Not Churn',
#   '537883': 'Churn',
#   '537884': 'Not Churn',
#   '537885': 'Not Churn',
#   '537886': 'Not Churn',
#   '537887': 'Not Churn',
#   '537888': 'Not Churn',
#   '537889': 'Not Churn',
#   '537890': 'Not Churn',
#   '537891': 'Not Churn',
#   '537892': 'Not Churn',
#   '537894': 'Not Churn',
#   '537895': 'Not Churn',
#   '537896': 'Not Churn',
#   '537897': 'Not Churn',
#   '537898': 'Not Churn',
#   '537899': 'Not Churn',
#   '537900': 'Not Churn',
#   '537901': 'Not Churn',
#   '537915': 'Churn',
#   '537955': 'Not Churn',
#   '537963': 'Churn',
#   '537967': 'Not Churn',
#   '537981': 'Not Churn',
#   '537995': 'Not Churn',
#   '538000': 'Not Churn',
#   '538002': 'Churn',
#   '538003': 'Not Churn',
#   '538005': 'Not Churn',
#   '538006': 'Not Churn',
#   '538007': 'Churn',
#   '538008': 'Not Churn',
#   '538009': 'Not Churn',
#   '538010': 'Not Churn',
#   '538011': 'Not Churn',
#   '538012': 'Not Churn',
#   '538013': 'Not Churn',
#   '538014': 'Not Churn',
#   '538015': 'Not Churn',
#   '538032': 'Not Churn',
#   '538035': 'Churn',
#   '538037': 'Not Churn',
#   '538040': 'Not Churn',
#   '538048': 'Churn',
#   '538049': 'Not Churn',
#   '538050': 'Not Churn',
#   '538051': 'Not Churn',
#   '538053': 'Not Churn',
#   '538056': 'Not Churn',
#   '538057': 'Not Churn',
#   '538063': 'Not Churn',
#   '538064': 'Not Churn',
#   '538065': 'Not Churn',
#   '538067': 'Not Churn',
#   '538068': 'Churn',
#   '538069': 'Churn',
#   '538070': 'Not Churn',
#   '538073': 'Not Churn',
#   '538076': 'Not Churn',
#   '538077': 'Not Churn',
#   '538078': 'Not Churn',
#   '538079': 'Not Churn',
#   '538080': 'Not Churn',
#   '538086': 'Not Churn',
#   '538087': 'Not Churn',
#   '538093': 'Not Churn',
#   '538094': 'Not Churn',
#   '538095': 'Not Churn',
#   '538097': 'Not Churn',
#   '538101': 'Not Churn',
#   '538104': 'Not Churn',
#   '538106': 'Not Churn',
#   '538107': 'Not Churn',
#   '538108': 'Churn',
#   '538113': 'Not Churn',
#   '538116': 'Not Churn',
#   '538117': 'Not Churn',
#   '538120': 'Not Churn',
#   '538125': 'Not Churn',
#   '538126': 'Not Churn',
#   '538145': 'Not Churn',
#   '538146': 'Not Churn',
#   '538147': 'Not Churn',
#   '538151': 'Not Churn',
#   '538155': 'Not Churn',
#   '538156': 'Not Churn',
#   '538157': 'Not Churn',
#   '538163': 'Not Churn',
#   '538165': 'Not Churn',
#   '538166': 'Not Churn',
#   '538167': 'Not Churn',
#   '538168': 'Not Churn',
#   '538169': 'Not Churn',
#   '538170': 'Not Churn',
#   '538171': 'Not Churn',
#   '538172': 'Not Churn',
#   '538174': 'Not Churn',
#   '538176': 'Not Churn',
#   '538178': 'Not Churn',
#   '538179': 'Not Churn',
#   '538180': 'Not Churn',
#   '538181': 'Not Churn',
#   '538182': 'Not Churn',
#   '538183': 'Not Churn',
#   '538184': 'Churn',
#   '538185': 'Not Churn',
#   '538186': 'Not Churn',
#   '538187': 'Churn',
#   '538190': 'Not Churn',
#   '538191': 'Not Churn',
#   '538192': 'Not Churn',
#   '538193': 'Not Churn',
#   '538194': 'Not Churn',
#   '538195': 'Not Churn',
#   '538196': 'Not Churn',
#   '538197': 'Not Churn',
#   '538198': 'Not Churn',
#   '538199': 'Churn',
#   '538200': 'Not Churn',
#   '538201': 'Churn',
#   '538202': 'Not Churn',
#   '538203': 'Not Churn',
#   '538204': 'Not Churn',
#   '538205': 'Not Churn',
#   '538206': 'Not Churn',
#   '538207': 'Not Churn',
#   '538208': 'Not Churn',
#   '538209': 'Not Churn',
#   '538210': 'Not Churn',
#   '538211': 'Not Churn',
#   '538216': 'Not Churn',
#   '538240': 'Not Churn',
#   '538248': 'Not Churn',
#   '538250': 'Not Churn',
#   '538252': 'Not Churn',
#   '538255': 'Not Churn',
#   '538260': 'Not Churn',
#   '538263': 'Not Churn',
#   '538268': 'Not Churn',
#   '538279': 'Not Churn',
#   '538280': 'Not Churn',
#   '538283': 'Not Churn',
#   '538288': 'Not Churn',
#   '538296': 'Not Churn',
#   '538306': 'Not Churn',
#   '538307': 'Not Churn',
#   '538308': 'Not Churn',
#   '538309': 'Not Churn',
#   '538310': 'Not Churn',
#   '538311': 'Churn',
#   '538312': 'Churn',
#   '538313': 'Not Churn',
#   '538327': 'Not Churn',
#   '538342': 'Not Churn',
#   '538343': 'Not Churn',
#   '538345': 'Not Churn',
#   '538346': 'Not Churn',
#   '538347': 'Not Churn',
#   '538352': 'Churn',
#   '538353': 'Not Churn',
#   '538354': 'Not Churn',
#   '538355': 'Not Churn',
#   '538356': 'Not Churn',
#   '538361': 'Not Churn',
#   '538363': 'Not Churn',
#   '538364': 'Not Churn',
#   '538365': 'Not Churn',
#   '538366': 'Not Churn',
#   '538367': 'Not Churn',
#   '538368': 'Churn',
#   '538369': 'Churn',
#   '538370': 'Not Churn',
#   '538371': 'Not Churn',
#   '538374': 'Not Churn',
#   '538378': 'Not Churn',
#   '538379': 'Not Churn',
#   '538382': 'Not Churn',
#   '538397': 'Not Churn',
#   '538403': 'Not Churn',
#   '538409': 'Not Churn',
#   '538417': 'Not Churn',
#   '538418': 'Not Churn',
#   '538419': 'Not Churn',
#   '538420': 'Not Churn',
#   '538421': 'Not Churn',
#   '538437': 'Not Churn',
#   '538449': 'Not Churn',
#   '538453': 'Not Churn',
#   '538470': 'Churn',
#   '538473': 'Not Churn',
#   '538488': 'Not Churn',
#   '538497': 'Not Churn',
#   '538499': 'Not Churn',
#   '538501': 'Not Churn',
#   '538503': 'Not Churn',
#   '538504': 'Not Churn',
#   '538507': 'Not Churn',
#   '538508': 'Not Churn',
#   '538509': 'Churn',
#   '538510': 'Churn',
#   '538511': 'Not Churn',
#   '538512': 'Churn',
#   '538513': 'Churn',
#   '538514': 'Not Churn',
#   '538515': 'Not Churn',
#   '538516': 'Not Churn',
#   '538517': 'Not Churn',
#   '538518': 'Not Churn',
#   '538519': 'Not Churn',
#   '538521': 'Not Churn',
#   '538522': 'Not Churn',
#   '538523': 'Not Churn',
#   '538525': 'Not Churn',
#   '538526': 'Not Churn',
#   '538527': 'Churn',
#   '538528': 'Not Churn',
#   '538529': 'Not Churn',
#   '538532': 'Not Churn',
#   '538533': 'Not Churn',
#   '538534': 'Not Churn',
#   '538535': 'Not Churn',
#   '538537': 'Not Churn',
#   '538541': 'Not Churn',
#   '538557': 'Not Churn',
#   '538558': 'Not Churn',
#   '538565': 'Not Churn',
#   '538567': 'Not Churn',
#   '538576': 'Not Churn',
#   '538591': 'Not Churn',
#   '538592': 'Not Churn',
#   '538593': 'Not Churn',
#   '538594': 'Not Churn',
#   '538596': 'Not Churn',
#   '538597': 'Not Churn',
#   '538625': 'Not Churn',
#   '538626': 'Not Churn',
#   '538629': 'Not Churn',
#   '538630': 'Not Churn',
#   '538631': 'Not Churn',
#   '538633': 'Not Churn',
#   '538634': 'Not Churn',
#   '538635': 'Churn',
#   '538636': 'Not Churn',
#   '538637': 'Not Churn',
#   '538638': 'Not Churn',
#   '538639': 'Not Churn',
#   '538640': 'Churn',
#   '538641': 'Not Churn',
#   '538644': 'Not Churn',
#   '538645': 'Not Churn',
#   '538646': 'Not Churn',
#   '538648': 'Not Churn',
#   '538651': 'Not Churn',
#   '538652': 'Not Churn',
#   '538653': 'Not Churn',
#   '538654': 'Not Churn',
#   '538655': 'Not Churn',
#   '538656': 'Not Churn',
#   '538657': 'Not Churn',
#   '538658': 'Not Churn',
#   '538659': 'Not Churn',
#   '538660': 'Not Churn',
#   '538661': 'Not Churn',
#   '538662': 'Not Churn',
#   '538663': 'Not Churn',
#   '538664': 'Not Churn',
#   '538665': 'Not Churn',
#   '538667': 'Not Churn',
#   '538668': 'Not Churn',
#   '538669': 'Not Churn',
#   '538671': 'Not Churn',
#   '538679': 'Not Churn',
#   '538683': 'Not Churn',
#   '538687': 'Not Churn',
#   '538688': 'Not Churn',
#   '538689': 'Not Churn',
#   '538697': 'Churn',
#   '538706': 'Not Churn',
#   '538707': 'Not Churn',
#   '538708': 'Churn',
#   '538709': 'Not Churn',
#   '538710': 'Not Churn',
#   '538714': 'Not Churn',
#   '538715': 'Not Churn',
#   '538716': 'Not Churn',
#   '538719': 'Not Churn',
#   '538721': 'Not Churn',
#   '538722': 'Not Churn',
#   '538744': 'Not Churn',
#   '538753': 'Not Churn',
#   '538783': 'Not Churn',
#   '538785': 'Not Churn',
#   '538795': 'Not Churn',
#   '538796': 'Not Churn',
#   '538797': 'Not Churn',
#   '538799': 'Not Churn',
#   '538800': 'Not Churn',
#   '538801': 'Not Churn',
#   '538807': 'Not Churn',
#   '538808': 'Not Churn',
#   '538809': 'Not Churn',
#   '538810': 'Not Churn',
#   '538811': 'Not Churn',
#   '538812': 'Not Churn',
#   '538814': 'Not Churn',
#   '538815': 'Not Churn',
#   '538816': 'Churn',
#   '538817': 'Not Churn',
#   '538826': 'Not Churn',
#   '538827': 'Not Churn',
#   '538828': 'Not Churn',
#   '538829': 'Not Churn',
#   '538830': 'Not Churn',
#   '538831': 'Not Churn',
#   '538832': 'Not Churn',
#   '538836': 'Not Churn',
#   '538839': 'Not Churn',
#   '538841': 'Not Churn',
#   '538843': 'Not Churn',
#   ...}}

# %% [markdown]
# #### PLOTTING THE ID3 DECISION TREE

# %%
x = df_1[['Quantity','UnitPrice']]
y = df_1['Churn']
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %% [markdown]
# #### 80/20 SPLIT

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 1)

# %%
# %matplotlib inline

clf = DecisionTreeClassifier(max_depth = 4000)
fig = clf.fit(x_train, y_train)
plt.figure(figsize = (20,15))
tree.plot_tree(fig, filled = True)
plt.show()

# %%
# MAGNIFIED VIEW

# %matplotlib inline

clf = DecisionTreeClassifier(max_depth = 3)
fig = clf.fit(x_train, y_train)
plt.figure(figsize = (20,15))
tree.plot_tree(fig, filled = True)
plt.show()

# %% [markdown]
# #### ACCURACY AND CLASSIFICATION REPORT

# %%
# ACCURACY OF ID3 DT

y_pred = clf.predict(x_test)
print("Accuracy % :", metrics.accuracy_score(y_test, y_pred) * 100)
# Out:
# Accuracy % : 98.58900709835298

# %%
# CLASSIFICATION REPORT OF ID3 DT
print("CONFUSION MATRIX:\n", confusion_matrix(y_test, y_pred))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, y_pred))
# Out:
# CONFUSION MATRIX:
#  [[    0   808]
#  [    5 56806]]
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#        Churn       0.00      0.00      0.00       808
#    Not Churn       0.99      1.00      0.99     56811
#
#     accuracy                           0.99     57619
#    macro avg       0.49      0.50      0.50     57619
# weighted avg       0.97      0.99      0.98     57619

# %% [markdown]
# ### ROC : AUC AND CURVE IN ID3

# %%
def ROC_Curve(y_test, y_pred):
    yt1 = y_test.map({"Churn": 1,"Not Churn": 0})
    yp1 = np.where(y_test == "Churn", 1, 0)
    # ROC AUC
    auc = roc_auc_score(yt1, yp1)
    print('ROC AUC: %f' % auc)

    # ROC Curve
    fpr, tpr, thresholds = roc_curve(yt1, yp1)
    font1 = {'family':'serif','color':'blue','size':20}
    font2 = {'family':'serif','color':'darkred','size':15}
    plt.plot([0, 1], [0, 1], linestyle = '--')
    plt.plot(fpr, tpr, marker = '.')
    plt.title("ROC CURVE", fontdict = font1)
    plt.xlabel("PREDICTION", fontdict = font2)
    plt.ylabel("TESTING", fontdict = font2)
    plt.show()
ROC_Curve(y_test, y_pred)
# Out:
# ROC AUC: 1.000000

# %% [markdown]
# ### SVM

# %%
#SVM
clf2 = LinearSVC(max_iter = 5000,verbose = True)
clf2.fit(x_train, y_train)
method = SVC(gamma = 'auto', kernel = 'rbf', C = 3.753) # SVC classifier passed to the Pipeline function.
clf2_2 = Pipeline([('scaler', StandardScaler()), ('svc', method)]) #Used as an estimator and avoid leaking the test set into the train set.
clf2_2.fit(x_train, y_train) # To fit the model obtained.
y_pred = clf2.predict(x_test)
# Out:
# [LibLinear]

# %% [markdown]
# #### ACCURACY AND CLASSIFICATION REPORT OF SVM

# %%
# CLASSIFICATION REPORT OF SVM
print("LINEAR SVM:\n")
print("Accuracy % :", metrics.accuracy_score(y_test, y_pred) * 100)
print("CONFUSION MATRIX:\n", confusion_matrix(y_test, y_pred))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, y_pred))
print("RBF SVM:\n")
print(clf2_2.score(x_test, y_test) * 100)
# Out:
# LINEAR SVM:
#
# Accuracy % : 98.5924781756018
# CONFUSION MATRIX:
#  [[    0   808]
#  [    3 56808]]
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#        Churn       0.00      0.00      0.00       808
#    Not Churn       0.99      1.00      0.99     56811
#
#     accuracy                           0.99     57619
#    macro avg       0.49      0.50      0.50     57619
# weighted avg       0.97      0.99      0.98     57619
#
# RBF SVM:
#
# 98.58900709835298

# %% [markdown]
# ### ROC : AUC AND CURVE IN SVM

# %%
ROC_Curve(y_test, y_pred)
# Out:
# ROC AUC: 1.000000

# %% [markdown]
# ### ANN

# %%
#ANN
clf3 = MLPClassifier(max_iter = 5000, verbose = True)
clf3 = clf3.fit(x_train, y_train)
y_pred = clf3.predict(x_test)
# Out:
# Iteration 1, loss = 0.10282470
# Iteration 2, loss = 0.07864294
# Iteration 3, loss = 0.07822238
# Iteration 4, loss = 0.07563560
# Iteration 5, loss = 0.07753069
# Iteration 6, loss = 0.07766999
# Iteration 7, loss = 0.07754805
# Iteration 8, loss = 0.07604078
# Iteration 9, loss = 0.07653252
# Iteration 10, loss = 0.07928821
# Iteration 11, loss = 0.08099358
# Iteration 12, loss = 0.07644377
# Iteration 13, loss = 0.07542815
# Iteration 14, loss = 0.07654819
# Iteration 15, loss = 0.07917803
# Iteration 16, loss = 0.08012774
# Iteration 17, loss = 0.07643909
# Iteration 18, loss = 0.07537057
# Iteration 19, loss = 0.07474333
# Iteration 20, loss = 0.07571476
# Iteration 21, loss = 0.07682908
# Iteration 22, loss = 0.07584297
# Iteration 23, loss = 0.07749245
# Iteration 24, loss = 0.07655167
# Iteration 25, loss = 0.07740303
# Iteration 26, loss = 0.07530750
# Iteration 27, loss = 0.08223928
# Iteration 28, loss = 0.07780841
# Iteration 29, loss = 0.07488440
# Iteration 30, loss = 0.07591913
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %% [markdown]
# #### ACCURACY AND CLASSIFICATION REPORT OF ANN

# %%
# CLASSIFICATION REPORT OF ANN
print("Accuracy % :", metrics.accuracy_score(y_test, y_pred) * 100)
print("CONFUSION MATRIX:\n", confusion_matrix(y_test, y_pred))
print("CLASSIFICATION REPORT:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy % : 98.59768479147503
# CONFUSION MATRIX:
#  [[    0   808]
#  [    0 56811]]
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#        Churn       0.00      0.00      0.00       808
#    Not Churn       0.99      1.00      0.99     56811
#
#     accuracy                           0.99     57619
#    macro avg       0.49      0.50      0.50     57619
# weighted avg       0.97      0.99      0.98     57619

# %% [markdown]
# ### ROC : AUC AND CURVE IN ANN

# %%
ROC_Curve(y_test, y_pred)
# Out:
# ROC AUC: 1.000000

# %% [markdown]
# ##### NOTE : All ```Evaluations``` and ```Comparative study``` for ID3, ANN and SVM are shown after their respective evaluations.
